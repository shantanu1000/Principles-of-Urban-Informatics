# %%
## Task 1 311_service_requests

import pandas as pd
import matplotlib.pyplot as plt


path = "D:\\Shantanu\\NYU CUSP\\PUI\\Assignment 1\\311_service_requests_2020.csv"

df = pd.read_csv(path)

# %%
df.head()
# Out:
#    case_enquiry_id              open_dt            target_dt closed_dt  \
# 0     101003156172  2020-01-10 11:32:00  2020-05-09 11:32:13       NaN
# 1     101003171366  2020-01-16 12:08:00  2021-01-15 12:09:19       NaN
# 2     101003175987  2020-01-22 15:34:00  2020-01-23 15:34:03       NaN
# 3     101003180345  2020-01-27 21:33:00  2020-02-11 08:30:00       NaN
# 4     101003183226  2020-01-30 14:55:58  2020-04-29 14:55:59       NaN
#
#     ontime case_status closure_reason                        case_title  \
# 0  OVERDUE        Open                 Unsatisfactory Living Conditions
# 1   ONTIME        Open                                New Tree Requests
# 2  OVERDUE        Open                      Sidewalk Repair (Make Safe)
# 3  OVERDUE        Open                                       PRINTED :
# 4  OVERDUE        Open                  Rental Unit Delivery Conditions
#
#                          subject               reason  ... police_district  \
# ...

# %%
df.columns
# Out:
# Index(['case_enquiry_id', 'open_dt', 'target_dt', 'closed_dt', 'ontime',
#        'case_status', 'closure_reason', 'case_title', 'subject', 'reason',
#        'type', 'queue', 'department', 'submittedphoto', 'closedphoto',
#        'location', 'fire_district', 'pwd_district', 'city_council_district',
#        'police_district', 'neighborhood', 'neighborhood_services_district',
#        'ward', 'precinct', 'location_street_name', 'location_zipcode',
#        'latitude', 'longitude', 'source'],
#       dtype='object')

# %%
len(df)
# Out:
# 161717

# %%
df.describe()
# Out:
#        case_enquiry_id  location_zipcode       latitude      longitude
# count     1.617170e+05     126496.000000  161717.000000  161717.000000
# mean      1.010033e+11       2126.907041      42.331518     -71.078489
# std       7.906295e+04         17.751533       0.034112       0.033925
# min       1.010031e+11       2108.000000      42.231500     -71.185400
# 25%       1.010032e+11       2119.000000      42.306100     -71.094500
# 50%       1.010033e+11       2126.000000      42.340600     -71.067100
# 75%       1.010033e+11       2130.000000      42.359400     -71.058700
# max       1.010034e+11       2467.000000      42.395200     -70.995100

# %%
df.subject.unique()
# Out:
# array(['Inspectional Services', 'Parks & Recreation Department',
#        'Public Works Department', 'Property Management',
#        "Mayor's 24 Hour Hotline", 'Transportation - Traffic Division',
#        'Animal Control', 'Boston Water & Sewer Commission',
#        'Boston Police Department', 'Consumer Affairs & Licensing',
#        'Neighborhood Services'], dtype=object)

# %%
len(df.subject.unique())
# Out:
# 11

# %%
len(df.reason.unique())
# Out:
# 43

# %%
len(df.type.unique())
# Out:
# 171

# %%
df.subject.unique()
# Out:
# array(['Inspectional Services', 'Parks & Recreation Department',
#        'Public Works Department', 'Property Management',
#        "Mayor's 24 Hour Hotline", 'Transportation - Traffic Division',
#        'Animal Control', 'Boston Water & Sewer Commission',
#        'Boston Police Department', 'Consumer Affairs & Licensing',
#        'Neighborhood Services'], dtype=object)

# %%
df.subject.value_counts()
# Out:
# Public Works Department              85739
# Transportation - Traffic Division    33328
# Inspectional Services                14022
# Mayor's 24 Hour Hotline              12207
# Parks & Recreation Department        10935
# Animal Control                        2196
# Property Management                   2170
# Boston Water & Sewer Commission        748
# Boston Police Department               344
# Consumer Affairs & Licensing            18
# Neighborhood Services                   10
# Name: subject, dtype: int64

# %%
df[['subject','case_enquiry_id']].groupby(by = 'subject').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='subject'>

# %%
df.neighborhood.unique()
# Out:
# array(['Dorchester', 'Hyde Park', 'Boston', 'Charlestown', 'East Boston',
#        'Back Bay', 'Mission Hill', 'Jamaica Plain', 'Beacon Hill',
#        'South Boston / South Boston Waterfront', 'Roxbury',
#        'Allston / Brighton', 'South End', 'Roslindale', 'West Roxbury',
#        ' ', 'Fenway / Kenmore / Audubon Circle / Longwood',
#        'Downtown / Financial District', 'South Boston',
#        'Greater Mattapan', 'Allston', nan, 'Brighton', 'Mattapan',
#        'Chestnut Hill'], dtype=object)

# %%
df.neighborhood.value_counts()
# Out:
# Dorchester                                      25580
# Roxbury                                         15391
# South Boston / South Boston Waterfront          12302
# Allston / Brighton                              11564
# East Boston                                     10938
# South End                                       10814
# Hyde Park                                        9127
# Jamaica Plain                                    8922
# Downtown / Financial District                    8140
# Greater Mattapan                                 7296
# Back Bay                                         7113
# West Roxbury                                     5857
# Roslindale                                       5688
# Charlestown                                      5402
# Boston                                           4224
# Beacon Hill                                      3272
# Fenway / Kenmore / Audubon Circle / Longwood     2750
# ...

# %%
df[['neighborhood', 'case_enquiry_id' ]].groupby(by = 'neighborhood').count().plot.bar()
# Out:
# <AxesSubplot:xlabel='neighborhood'>

# %%
## for 2132 rows the neighborhood is unnamed

# %%
## Task 2 Real Estate Data

# %%
pip install xlrd
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting xlrd
# ...
#      -------------------------------------- 96.5/96.5 kB 367.2 kB/s eta 0:00:00
# ...

# %%
path_2 = 'D:\\Shantanu\\NYU CUSP\\PUI\\Assignment 1\\2015_Brooklyn.xls'

df_2 = pd.read_excel(path_2, skiprows= 4)

# %%
df_2.head()
# Out:
#    BOROUGH\n             NEIGHBORHOOD\n  \
# 0          3  BATH BEACH
# 1          3  BATH BEACH
# 2          3  BATH BEACH
# 3          3  BATH BEACH
# 4          3  BATH BEACH
#
#                       BUILDING CLASS CATEGORY\n TAX CLASS AT PRESENT\n  \
# 0  01  ONE FAMILY DWELLINGS                                          1
# 1  01  ONE FAMILY DWELLINGS                                          1
# 2  01  ONE FAMILY DWELLINGS                                          1
# 3  01  ONE FAMILY DWELLINGS                                          1
# 4  01  ONE FAMILY DWELLINGS                                          1
#
#    BLOCK\n  LOT\n EASE-MENT\n BUILDING CLASS AT PRESENT\n  \
# 0     6360     22                                      A5
# 1     6361     17                                      A5
# 2     6371     60                                      A9
# 3     6372     48                                      S1
# 4     6373     73                                      A1
#
# ...

# %%
df_2.columns
# Out:
# Index(['BOROUGH\n', 'NEIGHBORHOOD\n', 'BUILDING CLASS CATEGORY\n',
#        'TAX CLASS AT PRESENT\n', 'BLOCK\n', 'LOT\n', 'EASE-MENT\n',
#        'BUILDING CLASS AT PRESENT\n', 'ADDRESS\n', 'APARTMENT NUMBER\n',
#        'ZIP CODE\n', 'RESIDENTIAL UNITS\n', 'COMMERCIAL UNITS\n',
#        'TOTAL UNITS\n', 'LAND SQUARE FEET\n', 'GROSS SQUARE FEET\n',
#        'YEAR BUILT\n', 'TAX CLASS AT TIME OF SALE\n',
#        'BUILDING CLASS AT TIME OF SALE\n', 'SALE PRICE\n', 'SALE DATE\n'],
#       dtype='object')

# %%
df_2['SALE PRICE\n'].sum()
# Out:
# 19990077327

# %%
df_2.describe()
# Out:
#        BOROUGH\n       BLOCK\n         LOT\n    ZIP CODE\n  \
# count    25362.0  25362.000000  25362.000000  25362.000000
# mean         3.0   4207.714534    281.084418  11217.017270
# std          0.0   2649.487442    492.384071    186.770716
# min          3.0     20.000000      1.000000      0.000000
# 25%          3.0   1768.000000     21.000000  11209.000000
# 50%          3.0   4149.000000     46.000000  11219.000000
# 75%          3.0   6540.000000    103.000000  11231.000000
# max          3.0   8955.000000   9033.000000  11249.000000
#
#        RESIDENTIAL UNITS\n  COMMERCIAL UNITS\n  TOTAL UNITS\n  \
# count         25362.000000        25362.000000   25362.000000
# mean              2.376981            0.185474       2.603817
# std               7.803233            2.711002       8.286863
# min               0.000000            0.000000       0.000000
# 25%               1.000000            0.000000       1.000000
# ...

# %%
df_2[['SALE PRICE\n', 'ZIP CODE\n']].groupby(by=['ZIP CODE\n']).mean()
# Out:
#             SALE PRICE\n
# ZIP CODE\n
# 0           4.892857e+05
# 11201       1.618065e+06
# 11203       4.190376e+05
# 11204       4.908219e+05
# 11205       7.062129e+05
# 11206       1.213060e+06
# 11207       4.006299e+05
# 11208       3.979557e+05
# 11209       5.333751e+05
# 11210       6.411172e+05
# 11211       1.272336e+06
# 11212       7.217267e+05
# 11213       7.467856e+05
# 11214       5.148053e+05
# 11215       1.200128e+06
# 11216       7.310867e+05
# 11217       1.619211e+06
# 11218       7.183455e+05
# 11219       4.863094e+05
# 11220       6.457887e+05
# 11221       5.739595e+05
# 11222       1.250622e+06
# 11223       6.056926e+05
# 11224       8.177449e+05
# 11225       1.114451e+06
# 11226       1.403538e+06
# 11227       6.000000e+05
# 11228       5.305021e+05
# 11229       4.220108e+05
# 11230       5.853335e+05
# 11231       1.539066e+06
# 11232       1.392873e+06
# 11233       5.631594e+05
# 11234       3.765121e+05
# 11235       4.385999e+05
# ...

# %%
df_2[['SALE PRICE\n', 'ZIP CODE\n']].groupby(by=['ZIP CODE\n']).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='ZIP CODE\n'>

# %%
Agg_df_2 = df_2[['SALE PRICE\n', 'GROSS SQUARE FEET\n','ZIP CODE\n']].groupby(by=['ZIP CODE\n']).sum()

Agg_df_2['Price_per_square_feet']= (Agg_df_2['SALE PRICE\n']/Agg_df_2['GROSS SQUARE FEET\n']).round(2)

Agg_df_2.sort_values(by = 'Price_per_square_feet', ascending = False)
# Out:
#             SALE PRICE\n  GROSS SQUARE FEET\n  Price_per_square_feet
# ZIP CODE\n
# 0                3425000                    0                    inf
# 11239             592000                    0                    inf
# 11249          989082814              1100543                 898.72
# 11201         1986984263              2634291                 754.28
# 11215         1202527889              2004753                 599.84
# 11217          816082437              1391185                 586.61
# 11222          577787347              1359457                 425.01
# 11231          612548434              1492092                 410.53
# 11211          891907730              2222272                 401.35
# 11238          914549280              2606097                 350.93
# 11206          657478647              1905171                 345.10
# 11218          476981418              1563861                 305.00
# ...

# %%
Agg_df_3 = Agg_df_2.sort_values(by = 'Price_per_square_feet', ascending = False).drop(labels = [0,11239], axis = 0)
Agg_df_3
# Out:
#             SALE PRICE\n  GROSS SQUARE FEET\n  Price_per_square_feet
# ZIP CODE\n
# 11249          989082814              1100543                 898.72
# 11201         1986984263              2634291                 754.28
# 11215         1202527889              2004753                 599.84
# 11217          816082437              1391185                 586.61
# 11222          577787347              1359457                 425.01
# 11231          612548434              1492092                 410.53
# 11211          891907730              2222272                 401.35
# 11238          914549280              2606097                 350.93
# 11206          657478647              1905171                 345.10
# 11218          476981418              1563861                 305.00
# 11209          437900992              1450713                 301.85
# 11223          448212521              1490493                 300.71
# ...

# %%
Agg_df_3['Price_per_square_feet'].plot.bar()
# Out:
# <AxesSubplot:xlabel='ZIP CODE\n'>

# %%
## Task 4
url = 'https://raw.githubusercontent.com/nychealth/coronavirus-data/7953c97d1e58bbed9934ea04affb12ca74d9c0fb/data-by-modzcta.csv'

df_COVID = pd.read_csv(url)

df_COVID. head()
# Out:
#    MODIFIED_ZCTA                        NEIGHBORHOOD_NAME BOROUGH_GROUP  \
# 0          10001               Chelsea/NoMad/West Chelsea     Manhattan
# 1          10002                Chinatown/Lower East Side     Manhattan
# 2          10003  East Village/Gramercy/Greenwich Village     Manhattan
# 3          10004                       Financial District     Manhattan
# 4          10005                       Financial District     Manhattan
#
#    COVID_CASE_COUNT  COVID_CASE_RATE  POP_DENOMINATOR  COVID_DEATH_COUNT  \
# 0               441          1871.58         23563.03                 26
# 1              1335          1739.29         76755.41                161
# 2               543          1009.26         53801.62                 35
# 3                40          1095.71          3650.61                  1
# 4                96          1143.39          8396.11                  2
#
#    COVID_DEATH_RATE  PERCENT_POSITIVE  TOTAL_COVID_TESTS
# ...

# %%
df_AGG_COVID = df_COVID[['BOROUGH_GROUP','COVID_CASE_COUNT']].groupby(by = 'BOROUGH_GROUP').sum()
df_AGG_COVID
# Out:
#                COVID_CASE_COUNT
# BOROUGH_GROUP
# Bronx                     50914
# Brooklyn                  61442
# Manhattan                 28684
# Queens                    68202
# Staten Island             14905

# %%
df_AGG_COVID.plot.bar()
# Out:
# <AxesSubplot:xlabel='BOROUGH_GROUP'>

# %%
df_percentage_COVIDCASES = df_COVID[['BOROUGH_GROUP','COVID_CASE_COUNT','TOTAL_COVID_TESTS']].groupby(by = 'BOROUGH_GROUP').sum()
df_percentage_COVIDCASES['%_of_POSITIVE_CASES']= (100*(df_percentage_COVIDCASES['COVID_CASE_COUNT']/df_percentage_COVIDCASES['TOTAL_COVID_TESTS'])).round(2)
df_percentage_COVIDCASES
# Out:
#                COVID_CASE_COUNT  TOTAL_COVID_TESTS  %_of_POSITIVE_CASES
# BOROUGH_GROUP
# Bronx                     50914             354513                14.36
# Brooklyn                  61442             571412                10.75
# Manhattan                 28684             429065                 6.69
# Queens                    68202             518597                13.15
# Staten Island             14905             110091                13.54

# %%
df_percentage_COVIDCASES['%_of_POSITIVE_CASES'].plot.bar(ylabel='%_of_POSITIVE_CASES' )
# Out:
# <AxesSubplot:xlabel='BOROUGH_GROUP', ylabel='%_of_POSITIVE_CASES'>

# %%
df_AGG_COVID_POP = df_COVID[['BOROUGH_GROUP','POP_DENOMINATOR','COVID_CASE_COUNT']].groupby(by = 'BOROUGH_GROUP').sum()
df_AGG_COVID_POP
# Out:
#                POP_DENOMINATOR  COVID_CASE_COUNT
# BOROUGH_GROUP
# Bronx               1434692.65             50914
# Brooklyn            2582829.99             61442
# Manhattan           1611943.49             28684
# Queens              2288709.82             68202
# Staten Island        476179.01             14905

# %%
df_AGG_COVID_POP['%_of_POP_WITH_COVID']= (100*(df_AGG_COVID_POP['COVID_CASE_COUNT']/df_AGG_COVID_POP['POP_DENOMINATOR'])).round(2)
df_AGG_COVID_POP
# Out:
#                POP_DENOMINATOR  COVID_CASE_COUNT  %_of_POP_WITH_COVID
# BOROUGH_GROUP
# Bronx               1434692.65             50914                 3.55
# Brooklyn            2582829.99             61442                 2.38
# Manhattan           1611943.49             28684                 1.78
# Queens              2288709.82             68202                 2.98
# Staten Island        476179.01             14905                 3.13

# %%
df_AGG_COVID_POP['%_of_POP_WITH_COVID'].plot.bar(ylabel='%_of_POP_WITH_COVID')
# Out:
# <AxesSubplot:xlabel='BOROUGH_GROUP', ylabel='%_of_POP_WITH_COVID'>

# %%
## Task 3 - Geopandas.......it is done in the end because there was a problem installing geopandas in anaconda, on my laptop

# %%
import geopandas as gpd

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/2cav-chmn?method=export&format=GeoJSON'
# alternative URL
url = 'https://raw.githubusercontent.com/CUSP2021PUI/Data/main/Street%20Pavement%20Rating.geojson'
rating = gpd.read_file(url)

# %%
rating.head()
# Out:
#   hagstrom bus segment_id     shape_leng truck rating_b usage_class  \
# 0        0   0         56  249.903981561     0        0        None
# 1        0   0         58  260.837113924     0        0        None
# 2        0   0         73  250.888421415     0        6        None
# 3        0   0        106  231.814581077     0        9        None
# 4        0   0        123  276.441675585     0        8        None
#
#   rating_fy_s length width rating_word               rating_date  \
# 0           0    414    30          NR                       NaT
# 1           0    425    30          NR                       NaT
# 2        2019    202    30        FAIR 2019-03-12 00:00:00+00:00
# 3        2019    232    30        GOOD 2019-03-12 00:00:00+00:00
# 4        2013    212    30        GOOD 2013-06-19 00:00:00+00:00
#
#                                             geometry
# 0  MULTILINESTRING ((-74.24916 40.49872, -74.2500...
# 1  MULTILINESTRING ((-74.24935 40.49944, -74.2502...
# ...

# %%
rating.iloc[:,:-1].describe()
# Out:
# C:\Users\Shantanu\AppData\Local\Temp\ipykernel_10992\2776315433.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   rating.iloc[:,:-1].describe()
#        hagstrom    bus segment_id     shape_leng  truck rating_b usage_class  \
# count     81209  81209      81209          81209  81209    81209       57698
# unique        2      2      81209          41590      2       11           3
# top           0      0         56  260.499520153      0        8           L
# freq      71660  68374          1            359  73352    25137       40816
# first       NaN    NaN        NaN            NaN    NaN      NaN         NaN
# last        NaN    NaN        NaN            NaN    NaN      NaN         NaN
#
#        rating_fy_s length  width rating_word                rating_date
# ...

# %%
rating['length'] = rating['length'].astype(int)
rating['length'].describe()
# Out:
# count    81209.000000
# mean       382.526321
# std        250.159451
# min          6.000000
# 25%        238.000000
# 50%        288.000000
# 75%        505.000000
# max       6795.000000
# Name: length, dtype: float64

# %%
rating['rating_word'].value_counts()
# Out:
# GOOD    47178
# FAIR    24732
# NR       8220
# POOR     1079
# Name: rating_word, dtype: int64

# %%
rating[['rating_word','length']].groupby(by=['rating_word']).sum()
# Out:
#                length
# rating_word
# FAIR          9291301
# GOOD         18521671
# NR            2824328
# POOR           427280

# %%
rating[['rating_word','length']].groupby(by=['rating_word']).sum().plot.pie(y='length')
# Out:
# <AxesSubplot:ylabel='length'>

# %%
rating.plot(column=None, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
rating.plot(column='rating_word',cmap='Spectral',figsize=(10,10),legend=True)
# Out:
# <AxesSubplot:>

# %%
rating[rating['rating_word']=='POOR'].plot(column='rating_word',cmap='Spectral',figsize=(10,10),legend=True)
# Out:
# <AxesSubplot:>
